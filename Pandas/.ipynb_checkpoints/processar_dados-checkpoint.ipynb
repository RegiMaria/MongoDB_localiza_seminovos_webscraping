# %%
import csv
import pandas as pd

# %%
# Replace caracteres:
# Read each CSV file
df_day3 = pd.read_csv('day3_128.csv')
df_day4 = pd.read_csv('day4_133.csv')
df_day5 = pd.read_csv('day5_141.csv')
df_day6 = pd.read_csv('day6_142.csv')
df_day7 = pd.read_csv('day7_139.csv')
df_day8 = pd.read_csv('day8_140.csv')
df_day9 = pd.read_csv('day9_144.csv')
df_day10 = pd.read_csv('day10_147.csv')
df_day11 = pd.read_csv('day11_150.csv')
df_day12 = pd.read_csv('day12_165.csv')
df_day13 = pd.read_csv('day13_166.csv')
df_day14 = pd.read_csv('day14_162.csv')
df_day15 = pd.read_csv('day15_171.csv')
df_day16 = pd.read_csv('day16_168.csv')
df_day17 = pd.read_csv('day17_177.csv')
df_day18 = pd.read_csv('day18_171.csv')
df_day19 = pd.read_csv('day19_167.csv')
df_day20 = pd.read_csv('day20_144.csv')

# Replace "|" with space in 'ano' and 'km':
df_day3['ano'] = df_day3['ano'].str.replace('|', ' ')
df_day3['km'] = df_day3['km'].str.replace('|', ' ')

df_day4['ano'] = df_day4['ano'].str.replace('|', ' ')
df_day4['km'] = df_day4['km'].str.replace('|', ' ')

df_day5['ano'] = df_day5['ano'].str.replace('|', ' ')
df_day5['km'] = df_day5['km'].str.replace('|', ' ')


df_day6['ano'] = df_day6['ano'].str.replace('|', ' ')
df_day6['km'] = df_day6['km'].str.replace('|', ' ')


df_day7['ano'] = df_day7['ano'].str.replace('|', ' ')
df_day7['km'] = df_day7['km'].str.replace('|', ' ')

df_day8['ano'] = df_day8['ano'].str.replace('|', ' ')
df_day8['km'] = df_day8['km'].str.replace('|', ' ')

df_day9['ano'] = df_day9['ano'].str.replace('|', ' ')
df_day9['km'] = df_day9['km'].str.replace('|', ' ')

df_day10['ano'] = df_day10['ano'].str.replace('|', ' ')
df_day10['km'] = df_day10['km'].str.replace('|', ' ')


df_day11['ano'] = df_day11['ano'].str.replace('|', ' ')
df_day11['km'] = df_day11['km'].str.replace('|', ' ')


df_day12['ano'] = df_day12['ano'].str.replace('|', ' ')
df_day12['km'] = df_day12['km'].str.replace('|', ' ')

df_day13['ano'] = df_day13['ano'].str.replace('|', ' ')
df_day13['km'] = df_day13['km'].str.replace('|', ' ')

df_day14['ano'] = df_day14['ano'].str.replace('|', ' ')
df_day14['km'] = df_day14['km'].str.replace('|', ' ')


df_day15['ano'] = df_day15['ano'].str.replace('|', ' ')
df_day15['km'] = df_day15['km'].str.replace('|', ' ')

df_day16['ano'] = df_day16['ano'].str.replace('|', ' ')
df_day16['km'] = df_day16['km'].str.replace('|', ' ')

df_day17['ano'] = df_day17['ano'].str.replace('|', ' ')
df_day17['km'] = df_day17['km'].str.replace('|', ' ')

df_day18['ano'] = df_day18['ano'].str.replace('|', ' ')
df_day18['km'] = df_day18['km'].str.replace('|', ' ')

df_day19['ano'] = df_day19['ano'].str.replace('|', ' ')
df_day19['km'] = df_day19['km'].str.replace('|', ' ')

df_day20['ano'] = df_day20['ano'].str.replace('|', ' ')
df_day20['km'] = df_day20['km'].str.replace('|', ' ')


# Save the modified DataFrames csv:
df_day3.to_csv('day3_128.csv', index=False)
df_day4.to_csv('day4_133.csv', index=False)
df_day5.to_csv('day5_141.csv', index =False)
df_day6.to_csv('day6_142.csv', index=False)
df_day7.to_csv('day7_139.csv', index=False)
df_day8.to_csv('day8_140.csv', index=False)
df_day9.to_csv('day9_144.csv', index=False)
df_day10.to_csv('day10_147.csv',index=False)
df_day11.to_csv('day11_150.csv',index=False)
df_day12.to_csv('day12_165.csv',index=False)
df_day13.to_csv('day13_166.csv',index=False)
df_day14.to_csv('day14_162.csv',index=False)
df_day15.to_csv('day15_171.csv',index=False)
df_day16.to_csv('day16_168.csv',index=False)
df_day17.to_csv('day17_177.csv',index=False)
df_day18.to_csv('day18_171.csv',index=False)
df_day19.to_csv('day19_167.csv',index=False)
df_day20.to_csv('day20_144.csv',index=False)
